# %% [markdown]
# # Import Necessary Libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Importing and Observing the Dataset

# %%
df = pd.read_csv('gold_price.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2011-12-15  154.740005  154.949997  151.710007  152.330002  152.330002
# 1     2011-12-16  154.309998  155.369995  153.899994  155.229996  155.229996
# 2     2011-12-19  155.479996  155.860001  154.360001  154.869995  154.869995
# 3     2011-12-20  156.820007  157.429993  156.580002  156.979996  156.979996
# 4     2011-12-21  156.979996  157.529999  156.130005  157.160004  157.160004
# ...          ...         ...         ...         ...         ...         ...
# 1713  2018-12-24  119.570000  120.139999  119.570000  120.019997  120.019997
# 1714  2018-12-26  120.620003  121.000000  119.570000  119.660004  119.660004
# 1715  2018-12-27  120.570000  120.900002  120.139999  120.570000  120.570000
# 1716  2018-12-28  120.800003  121.080002  120.720001  121.059998  121.059998
# 1717  2018-12-31  120.980003  121.260002  120.830002  121.250000  121.250000
#
#         Volume     SP_open     SP_high      SP_low  ...    GDX_Low  GDX_Close  \
# 0     21521900  123.029999  123.199997  121.989998  ...  51.570000  51.680000
# 1     18124300  122.230003  122.949997  121.300003  ...  52.040001  52.680000
# 2     12547200  122.059998  122.320000  120.029999  ...  51.029999  51.169998
# 3      9136300  122.180000  124.139999  120.370003  ...  52.369999  52.990002
# 4     11996100  123.930000  124.360001  122.750000  ...  52.419998  52.959999
# ...        ...         ...         ...         ...  ...        ...        ...
# 1713   9736400  239.039993  240.839996  234.270004  ...  20.650000  21.090000
# 1714  14293500  235.970001  246.179993  233.759995  ...  20.530001  20.620001
# 1715  11874400  242.570007  248.289993  238.960007  ...  20.700001  20.969999
# 1716   6864700  249.580002  251.399994  246.449997  ...  20.570000  20.600000
# 1717   8449400  249.559998  250.190002  247.470001  ...  20.559999  21.090000
#
#       GDX_Adj Close  GDX_Volume   USO_Open   USO_High    USO_Low  USO_Close  \
# 0         48.973877    20605600  36.900002  36.939999  36.049999  36.130001
# 1         49.921513    16285400  36.180000  36.500000  35.730000  36.270000
# 2         48.490578    15120200  36.389999  36.450001  35.930000  36.200001
# 3         50.215282    11644900  37.299999  37.610001  37.220001  37.560001
# 4         50.186852     8724300  37.669998  38.240002  37.520000  38.110001
# ...             ...         ...        ...        ...        ...        ...
# 1713      21.090000    60507000   9.490000   9.520000   9.280000   9.290000
# 1714      20.620001    76365200   9.250000   9.920000   9.230000   9.900000
# 1715      20.969999    52393000   9.590000   9.650000   9.370000   9.620000
# 1716      20.600000    49835000   9.540000   9.650000   9.380000   9.530000
# 1717      21.090000    53866600   9.630000   9.710000   9.440000   9.660000
#
#       USO_Adj Close  USO_Volume
# 0         36.130001    12616700
# 1         36.270000    12578800
# 2         36.200001     7418200
# 3         37.560001    10041600
# 4         38.110001    10728000
# ...             ...         ...
# 1713       9.290000    21598200
# 1714       9.900000    40978800
# 1715       9.620000    36578700
# 1716       9.530000    22803400
# 1717       9.660000    28417400
#
# [1718 rows x 81 columns]

# %% [markdown]
# Here, we have 1718 rows and 81 columns. I'll only be using the Date, Adjusted Closed Price and Volume column.

# %%
df = df.loc[:,['Date','Adj Close','Volume']]
df
# Out:
#             Date   Adj Close    Volume
# 0     2011-12-15  152.330002  21521900
# 1     2011-12-16  155.229996  18124300
# 2     2011-12-19  154.869995  12547200
# 3     2011-12-20  156.979996   9136300
# 4     2011-12-21  157.160004  11996100
# ...          ...         ...       ...
# 1713  2018-12-24  120.019997   9736400
# 1714  2018-12-26  119.660004  14293500
# 1715  2018-12-27  120.570000  11874400
# 1716  2018-12-28  121.059998   6864700
# 1717  2018-12-31  121.250000   8449400
#
# [1718 rows x 3 columns]

# %% [markdown]
# # Correcting the Date Time Format on the Date Column

# %%
# Assuming 'Date' is not in the correct format
# If it's already in datetime format, you can skip this step
df['Date'] = pd.to_datetime(df['Date'])

# Set the 'Date' column as the index for time series analysis
df.set_index('Date', inplace=True)

# Now, you can analyze daily data using various time series techniques
# For example, you can resample the data to daily frequency and compute statistics
# daily_df = df.resample('D').mean()
# Ours is already showing daily data so we are skipping this step

# %%
df
# Out:
#              Adj Close    Volume
# Date
# 2011-12-15  152.330002  21521900
# 2011-12-16  155.229996  18124300
# 2011-12-19  154.869995  12547200
# 2011-12-20  156.979996   9136300
# 2011-12-21  157.160004  11996100
# ...                ...       ...
# 2018-12-24  120.019997   9736400
# 2018-12-26  119.660004  14293500
# 2018-12-27  120.570000  11874400
# 2018-12-28  121.059998   6864700
# 2018-12-31  121.250000   8449400
#
# [1718 rows x 2 columns]

# %%
df.describe()
# Out:
#          Adj Close        Volume
# count  1718.000000  1.718000e+03
# mean    127.319482  8.446327e+06
# std      17.536269  4.920731e+06
# min     100.500000  1.501600e+06
# 25%     116.052502  5.412925e+06
# 50%     121.795002  7.483900e+06
# 75%     128.470001  1.020795e+07
# max     173.610001  9.380420e+07

# %% [markdown]
# # Time Series Data Visualization:

# %%
# Plotting the 'Adj Close' over time
plt.figure(figsize=(20, 6))
plt.plot(df['Adj Close'])
plt.title('Daily Adjusted Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()

# %%
# Plotting the 'Volume' over time
plt.figure(figsize=(20, 6))
plt.plot(df['Volume'])
plt.title('Daily Shares Traded Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %%
plt.figure(figsize=(20, 6))
df['Adj Close'].resample(rule= 'A').min().plot()
plt.show()
# This shows the minimum stock prices for every year (Annual Minimum) in the dataset

# %%
plt.figure(figsize=(20, 6))
df['Adj Close'].resample(rule= 'A').max().plot()
plt.show()
# This shows the maximum stock prices for every year (Annual Minimum) in the dataset

# %%
plt.figure(figsize=(20, 6))
df['Adj Close'].resample(rule= 'M').min().plot()
plt.show()
# This shows the minimum stock prices for every Month (Monthly Minimum) in the dataset

# %%
plt.figure(figsize=(20, 6))
df['Adj Close'].resample(rule= 'M').max().plot()
plt.show()
# This shows the maximum stock prices for every Month (Monthly Minimum) in the dataset

# %%
plt.figure(figsize=(20, 6))
df['Adj Close'].resample(rule= 'BQS').min().plot()
plt.show()
# This shows the minimum stock prices for every Business Quarter in the dataset

# %%
plt.figure(figsize=(20, 6))
df['Adj Close'].resample(rule= 'BQS').max().plot()
plt.show()
# This shows the maximum stock prices for every Business Quarter in the dataset

# %%
plt.figure(figsize=(20, 6))
df['Adj Close'].resample(rule= 'W').min().plot()
plt.show()
# This shows the minimum stock prices for every week in the dataset

# %%
plt.figure(figsize=(20, 6))
df['Adj Close'].resample(rule= 'W').max().plot()
plt.show()
# This shows the maximum stock prices for every week in the dataset

# %% [markdown]
# # Daily Returns (%) Calculation:
#
# We assume an investor started investing on Gold during the start date of this data set. We will do Normalization on the dataset to set the initial stock price at $1 ,to calculate how much return he is getting for each Dollar he invested.

# %%
# print out normalized (scaled) stock prices

def normalize(df):
  x = df.copy() # make a copy of my dataframe
  for i in x.columns[:]:
    x[i] = x[i]/(x[i][0]) #taking all the values in a column and dividing by the first value of that column
  return x
# now call the function
df_2 = normalize(df)
df_2
# Out:
#             Adj Close    Volume
# Date
# 2011-12-15   1.000000  1.000000
# 2011-12-16   1.019038  0.842133
# 2011-12-19   1.016674  0.582997
# 2011-12-20   1.030526  0.424512
# 2011-12-21   1.031707  0.557390
# ...               ...       ...
# 2018-12-24   0.787895  0.452395
# 2018-12-26   0.785531  0.664137
# 2018-12-27   0.791505  0.551736
# 2018-12-28   0.794722  0.318963
# 2018-12-31   0.795969  0.392595
#
# [1718 rows x 2 columns]

# %%
# Plotting the 'Adj Close' over time
plt.figure(figsize=(20, 6))
plt.plot(df_2['Adj Close'])
plt.title('Daily Adjusted Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()

# %%
# Plotting the 'Volume' over time
plt.figure(figsize=(20, 6))
plt.plot(df_2['Volume'])
plt.title('Daily Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()

# %%
# Create a new column for daily returns
df_2['Daily Return'] = ((df_2['Adj Close'] - df_2['Adj Close'].shift(1)) / df_2['Adj Close'].shift(1)) * 100

# Set the first value of the 'Daily Return' column to 0
df_2['Daily Return'].iloc[0] = 0

# Print the DataFrame with the new 'Daily Return' column
print(df_2)
# Out:
#             Adj Close    Volume  Daily Return
# Date
# 2011-12-15   1.000000  1.000000      0.000000
# 2011-12-16   1.019038  0.842133      1.903758
# 2011-12-19   1.016674  0.582997     -0.231915
# 2011-12-20   1.030526  0.424512      1.362434
# 2011-12-21   1.031707  0.557390      0.114669
# ...               ...       ...           ...
# 2018-12-24   0.787895  0.452395      1.095010
# 2018-12-26   0.785531  0.664137     -0.299944
# 2018-12-27   0.791505  0.551736      0.760485
# 2018-12-28   0.794722  0.318963      0.406401
# 2018-12-31   0.795969  0.392595      0.156949
#
# [1718 rows x 3 columns]

# %%
# Plotting the 'Daily Returns' over time
plt.figure(figsize=(20, 6))
plt.plot(df_2['Daily Return'])
plt.title('Daily Return % Over Time')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()

# %%
sns.distplot(df_2['Adj Close'])
# Out:
# <ipython-input-22-3b9dd65a92c8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2['Adj Close'])
# <Axes: xlabel='Adj Close', ylabel='Density'>

# %%
sns.distplot(df_2['Volume'])
# Out:
# <ipython-input-23-d1435bd4e57f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2['Volume'])
# <Axes: xlabel='Volume', ylabel='Density'>

# %%
sns.distplot(df_2['Daily Return'])
# Out:
# <ipython-input-24-3369f9849d4b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2['Daily Return'])
# <Axes: xlabel='Daily Return', ylabel='Density'>

# %% [markdown]
# # Time Series Forecasting:
#
# ![Screenshot (11).png](data:image/png;base64,...)

# %% [markdown]
# # Step-1: Check for Trend and Seasonality:

# %%
from statsmodels.tsa.seasonal import seasonal_decompose


# Decompose the time series into trend, seasonal, and residual components
result = seasonal_decompose(df['Adj Close'], model='additive', period= 365)

# Plot the decomposed components
plt.figure(figsize=(20, 8))
result.plot()
plt.title('Seasonal Decomposition of Time Series')
plt.show()

# Check if there is a trend
if result.trend is not None:
    print("The time series has a trend.")
else:
    print("The time series does not have a trend.")

# Check if there is seasonality
if result.seasonal is not None:
    print("The time series has seasonality.")
else:
    print("The time series does not have seasonality.")
# Out:
# The time series has a trend.
# The time series has seasonality.

# %% [markdown]
# So, We will use Holt Winter's Additive Seasonality Model with Trend.

# %% [markdown]
# # Step-2: Forecasting using Holt Winters Seasonality Model with Trend:

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing


ts = df['Adj Close']

# Split the data into training and testing sets
# You can adjust the split point based on your specific requirements
train_size = int(len(ts) * 0.8)
train, test = ts[:train_size], ts[train_size:]

# Build the Holt-Winters Additive Seasonality model with trend
model = ExponentialSmoothing(train, trend='add', seasonal='add', seasonal_periods=365)
result = model.fit()

# Make predictions for the test set
predictions = result.forecast(len(test))

# Plot the original time series and the forecast
plt.figure(figsize=(20, 10))
plt.plot(train.index, train, label='Training Data')
plt.plot(test.index, test, label='Testing Data')
plt.plot(test.index, predictions, label='Forecast')
plt.title('Holt-Winters Additive Seasonality Forecast')
plt.xlabel('Date')
plt.ylabel('Adjusted Closing Price')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
# Model Evaluation:

from sklearn.metrics import mean_squared_error
# Calculate the Mean Squared Error (MSE)
mse = mean_squared_error(test, predictions)

# Calculate the Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 11.195942000917466

# %% [markdown]
# # Step-3: Forecasting using Recurrent Neural Networks:

# %%
train.shape
# Out:
# (1374,)

# %%
test.shape
# Out:
# (344,)

# %%
X_train = []
y_train = []

# let's take the first 1374 (80 %) datapoints as training data

for i in range(30, len(train)):
    X_train.append(train[i-30:i]) # i want to forecast next day gold price (based on 30 days data of the past)
    y_train.append(train[i])


X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshaping Data for inputing into Keras

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# ***NOTE:***
# Here, x and y are 2D array(observation and features) into a 3D array where the 3rd dimension will include the timestamp.
#
# why do we do this?
# Keras requires 3D tensor with shape (batch_size, timestamps, input_dim) as input. here, our input_dim is =1 (stock price at time 't')

# %%
# now, lets take remaining 20% of data as testing set

X_test = []
for i in range(30,len(test)):
    X_test.append(test[i-30:i])

X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

regressor = Sequential()

# Input Layer
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# 1st Hidden Layer
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# 2nd Hidden Layer
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# 3rd Hidden Layer
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Output Layer
regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(X_train, y_train, epochs =
# 42/42 [==============================] - 2s 47ms/step - loss: 91.0954
# Epoch 478/500
# 42/42 [==============================] - 2s 46ms/step - loss: 79.7199
# Epoch 479/500
# 42/42 [==============================] - 2s 46ms/step - loss: 86.3981
# Epoch 480/500
# 42/42 [==============================] - 2s 47ms/step - loss: 86.7637
# Epoch 481/500
# 42/42 [==============================] - 3s 75ms/step - loss: 87.9192
# Epoch 482/500
# 42/42 [==============================] - 2s 53ms/step - loss: 88.6082
# Epoch 483/500
# 42/42 [==============================] - 2s 46ms/step - loss: 95.9427
# Epoch 484/500
# 42/42 [==============================] - 2s 46ms/step - loss: 88.2095
# Epoch 485/500
# 42/42 [==============================] - 2s 47ms/step - loss: 86.8530
# Epoch 486/500
# 42/42 [==============================] - 2s 47ms/step - loss: 85.9385
# Epoch 487/500
# 42/42 [==============================] - 3s 67ms/step - loss: 85.8137
# Epoch 488/500
# 42/42 [==============================] - 3s 63ms/step - loss: 85.6344
# Epoch 489/500
# 42/42 [==============================] - 2s 47ms/step - loss: 88.3183
# Epoch 490/500
# 42/42 [==============================] - 2s 48ms/step - loss: 84.0589
# Epoch 491/500
# 42/42 [==============================] - 2s 47ms/step - loss: 89.3832
# Epoch 492/500
# 42/42 [==============================] - 2s 48ms/step - loss: 88.4052
# Epoch 493/500
# 42/42 [==============================] - 2s 60ms/step - loss: 82.9689
# Epoch 494/500
# 42/42 [==============================] - 3s 69ms/step - loss: 87.6537
# Epoch 495/500
# 42/42 [==============================] - 2s 47ms/step - loss: 85.7583
# Epoch 496/500
# 42/42 [==============================] - 2s 47ms/step - loss: 81.2383
# Epoch 497/500
# 42/42 [==============================] - 2s 47ms/step - loss: 86.5613
# Epoch 498/500
# 42/42 [==============================] - 2s 46ms/step - loss: 88.5377
# Epoch 499/500
# 42/42 [==============================] - 2s 52ms/step - loss: 84.7571
# Epoch 500/500
# 42/42 [==============================] - 3s 64ms/step - loss: 92.0069

# %%
pred = regressor.predict(X_test)
# Out:
# 10/10 [==============================] - 2s 16ms/step

# %%
# Reshape predictions to 1D array
y_pred_1d = pred.flatten()

# Plot the training, testing, and forecasted data
plt.figure(figsize=(20, 10))
plt.plot(train.index, train, label='Training Data')
plt.plot(test.index, test, label='Testing Data')
plt.plot(test.index[:-30], y_pred_1d, label='Forecast')  # Adjust indexing to match lengths
plt.title('Forecast using RNN Model')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Reshape predictions and true values to 1D arrays
y_true_1d = test.values[:len(y_pred_1d)].flatten()

# Calculate Root Mean Squared Error (RMSE)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_true_1d, y_pred_1d)
rmse = np.sqrt(mse)

print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Root Mean Squared Error (RMSE): 3.1875642156569066

# %% [markdown]
# Now, we can finally decide which model to use. RNN is the winner here as it's RMSE value is very low compared to the Holt-Winter's Seasonal Model with trend.

# %% [markdown]
# # Save the Model:

# %%
from tensorflow.keras.models import load_model

regressor.save('RNN Model for Gold Price Prediction (Time Series).h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Load the Model:

# %%
my_model = load_model('RNN Model for Gold Price Prediction (Time Series).h5')

# %%
X_test.shape

# %% [markdown]
# ***Note:*** Please note the shape of X_test used to predict the model during its creation stage. The Data that you input must be a 3D array shape. For Reshaping the input data into a 3D format use the following Code Snippet:
#
#
# ```
# input = []
# for i in range(7,len(input_df)):
#     input.append(input_df[i-7:i])
# input_array = np.array(input)
# input_3D = np.reshape(input_array, (input_array.shape[0], input_array.shape[1], 1))
#
# ```
# Here, How many days in the past you want to predict the next days price = 7 (for example) and input_df must have 'Date' column as index and a second column containing the prices.

# %% [markdown]
# # Predicting Unseen Data:
#
# (Here, we'll be using some random made up data to just see if the model works or not)

# %%
df = pd.read_csv('random_price.csv')
# Assuming 'Date' is not in the correct format
# If it's already in datetime format, you can skip this step
df['Date'] = pd.to_datetime(df['Date'])

# Set the 'Date' column as the index for time series analysis
df.set_index('Date', inplace=True)

df
# Out:
#                  Price
# Date
# 2020-06-02  323.339996
# 2020-06-03  325.119995
# 2020-06-04  322.320007
# 2020-06-05  331.500000
# 2020-06-08  333.459991
# 2020-06-09  343.989990
# 2020-06-10  352.839996
# 2020-06-11  335.899994
# 2020-06-12  338.799988
# 2020-06-15  342.989990
# 2020-06-16  352.079987
# 2020-06-17  351.589996
# 2020-06-18  351.730011
# 2020-06-19  349.720001
# 2020-06-22  358.869995
# 2020-06-23  366.529999
# 2020-06-24  360.059998
# 2020-06-25  364.839996
# 2020-06-26  353.630005
# 2020-06-29  361.779999
# 2020-06-30  364.799988
# 2020-07-01  364.109985
# 2020-07-02  364.109985
# 2020-07-06  373.850006
# 2020-07-07  372.690002
# 2020-07-08  381.369995
# 2020-07-09  383.010010
# 2020-07-10  383.679993
# 2020-07-13  381.910004
# 2020-07-14  388.230011
# 2020-07-15  390.899994
# 2020-07-16  386.089996
# 2020-07-17  385.309998
# 2020-07-20  393.429993
# 2020-07-21  388.000000
# 2020-07-22  389.089996
# 2020-07-23  371.380005
# 2020-07-24  370.459991
# 2020-07-27  379.239990
# 2020-07-28  373.010010
# 2020-07-29  380.160004
# 2020-07-30  384.760010
# 2020-07-31  425.040009
# 2020-08-03  435.750000
# 2020-08-04  438.660004
# 2020-08-05  440.250000
# 2020-08-06  455.609985
# 2020-08-07  444.450012
# 2020-08-10  450.910004
# 2020-08-11  437.500000

# %%
df.shape
# Out:
# (50, 1)

# %%
input = []
for i in range(30,len(df)):
    input.append(df[i-30:i])
input_array = np.array(input)
input_3D = np.reshape(input_array, (input_array.shape[0], input_array.shape[1], 1))

# %%
pred = my_model.predict(input_3D)
pred
# Out:
# 1/1 [==============================] - 2s 2s/step
# array([[166.69577],
#        [166.69316],
#        [166.69057],
#        [166.68834],
#        [166.68637],
#        [166.68477],
#        [166.68295],
#        [166.6808 ],
#        [166.67892],
#        [166.67741],
#        [166.6762 ],
#        [166.67494],
#        [166.67368],
#        [166.67229],
#        [166.6711 ],
#        [166.66977],
#        [166.66817],
#        [166.66629],
#        [166.66417],
#        [166.6622 ]], dtype=float32)

# %%
pred.shape
# Out:
# (20, 1)

# %% [markdown]
# # Yay!! My model works!
